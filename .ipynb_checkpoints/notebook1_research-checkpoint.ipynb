# %% [markdown]
# # Training Autonomous Vehicles using Augmented Random Search (ARS) in Carla

# %% [markdown]
# ## Outline
# [Project Abstract](#abstract)<br>
# The abstract of the project, summarizing the goals, research, methodology, and conclusion.
#
# [The Math Behind ARS](#ars_math)<br>
# This section explains the mechanics of the ARS learning process.
#
# [Testing Car Environment with ARS](#testing_environment)<br>
# This section involves testing a modified version of Sentdex's Carla 'CarEnv' environment in the [framework for ARS learning provided by Colin Skow](https://github.com/colinskow/move37/tree/master/ars), which has also been modified to make use of the environment.<br>
#
# [Parallel Training using Ray](notebook2_train_agent.ipynb)<br>
# This notebook makes use of a version of the [ARS framework made available by the authors of the 2018 ARS paper](https://github.com/modestyachts/ARS) that has been modified to make use of the modified Sentdex 'CarEnv' environment in a parallel fashion using a Ray cluster. This allows multiple workers to explore deltas simultaneously and pool the results of their rollouts at each update step, leading to faster training of the agent.
#
# [Analysis of Results and Conclusions](notebook3_results_analysis.ipynb)<br>
# This notebook reviews and analyzes the results obtained from the first round of training, and provides the conclusions of this study.

# %% [markdown]
# ## Abstract
# [Carla](https://carla.org/) is an open source driving simulator with a Python API used for autonomous driving research. Built on Unreal Engine 4, it employs high-end graphics to provide a suitable representation of the real world conducive for reinforcement learning with camera data. This research sought to test the ability of the [Augmented Random Searching (ARS) algorithm](https://arxiv.org/pdf/1803.07055.pdf) to train a self-driving car policy on the data gathered from a single front-facing camera per car. ARS is an exciting new algorithm for reinforcement learning (RL) proposed in 2018 by Mania, Guy, and Recht, which has been shown to achieve competitive results on benchmark MuJoCo continuous control locomotion tasks compared to more complex model-free methods, while offering at least 15x more computational efficiency. This significant reduction in computational resource requirements makes it an attractive algorithm for small-scale autonomous vehicle research, and so it was chosen for this study.
#
# Code for usable car environment for this task was derived from a [Sentdex tutorial on using Carla for Deep Q-Learning](https://pythonprogramming.net/introduction-self-driving-autonomous-cars-carla-python/) and modified to fit the context of ARS learning. The modified environment was then tested by splicing it into [ARS code provided by Colin Skow](https://github.com/colinskow/move37/tree/master/ars) as a part of his course on RL. Once the environment was functional with ARS learning, the ability to train in parallel was achieved by modifying the [code provided by the authors of the ARS study](https://github.com/modestyachts/ARS) to make use of this car environment. This allowed testing of the efficacy of this efficient learning algorithm on training autonomous vehicles using camera data from Carla. To convert the raw RGB camera data into edge-case representations, it was first passed through the pretrained VGG19 convolutional neural network using imagenet weights, without the top layer.
#
# A reward system was devised which penalized collisions, extreme values for steering control, and sitting stationary, while rewarding traveling at speed especially when moving in straight lines. Much experimentation was done in creating this reward system, but it is likely that more adjustments need to be made in the future to facilitate the learning process.
#
# Even despite the simplicity of the ARS algorithm, the personal computer used for training was only able to handle training with 4 workers in parallel due to the high computational demands of the Carla simulator, and this led to the process of learning being slow. Testing a range of hyperparameter values for learning rate, number of deltas tested/used, and delta std would require multiple deployments of a multi-day training process, and it is understandable that optimal balance of these parameter values for this task has not been found by this study, which only represents the first attempt at training using this framework. Instructions for running the parallelized training process can be found in the '[notebook2_train_agent](notebook2_train_agent.ipynb)' notebook.
#
# An in-depth review and analysis of the results of the training can be found in the '[notebook3_results_analysis](notebook3_results_analysis.ipynb)' notebook in this repository, along with the conclusions of this study. In summary, the first 5-day round of training did not lead to a noticably improving policy for the agent by the end of the 1250 iteration training period. It is possible that the learning rate and delta std was set too high for this task, and further testing using different values is needed. It may also be necessary to control the variability of the circumstances that each delta is tested on by controlling the spawning position of a worker, so that more fair comparisons may be made between the rewards achieved by positive and negative addition of each delta to the current policy, reducing the element of luck that a worker might experience based on starting position. Further, the reward system likely needs adjustment, as it is possible that the penalty for collisions was too high, leading the agent to too highly prioritize avoiding the collisions which it needed to be experiencing in order to learn the edge cases they were associated with. Finally, it is possible that 1250 training episodes was simply not enough time for meaningful progress to be made with training the agent. As can be seen in the '[ars_practice](ars_practice.ipynb)' notebook, the BipedalWalker-v3  (a much simpler environment from the gym module which always starts workers with an identical initial state) required 600 training steps before the algorithm began to make noticeable improvements to the policy. In the context of Carla, with so many unique scenarios for workers to find themselves in, it is understandable that this number of training episodes could be expected to be far larger. Scaling this research up onto more powerful hardware would help to answer this question.
#
# Below is a graphic summarizing the results of the training period of this study, which was just over 5 days (121.43 hours). Learning rate and delta std decay was applied, so the changing values of these hyperparameters over time is shown.
#
# ![Training Results](images/training_results.png)

# %% [markdown]
# <a id='ars_math'></a>
# ## The Math Behind ARS
# To understand what happens under the hood during the ARS learning process, let's take a look at the equation found in the 2018 paper, which I have annotated for clarity.<br>
# ![ARS Formula](images/ars_formula_explained.png)<br>
# In words, a user-defined number of deltas (random noise arrays with the same shape as the weights) are generated for each update step, and each delta is applied on 2 separate episodes: one in which it is added to the weights (positive direction) and one in which it is subtracted from the weights (negative direction). The rewards produced from the positive and negative directions are stored with their corresponding delta. Then the deltas are organized in order of maximum rewards produced in either the positive or negative direction, and then a user-defined number of the top performing deltas (up to the total number of deltas) are used in the update step (# deltas used). Each of the used deltas is multiplied by the difference between the rewards of the positive direction and the rewards of the negative direction corresponding to that delta, standardized by dividing these rewards by the collective standard deviation of all positive and negative rewards recorded from the deltas used during this step, which allows us to disregard the actual numerical scale of the reward system at hand. This effectively scales each delta by the magnitude of impact it had on performance, and reverses the sign when the negative direction has higher rewards than the positive direction. The result of each of these multiplication steps is then averaged by summing them together and dividing by the number of deltas used. The result is multiplied by the learning rate, then added to the weights, completing the update step.

# %% [markdown]
# <a id='testing_environment'></a>
# ## Testing Car Environment with ARS
# Now that we have an understanding of the ARS process, let's look at how we can fit [Sentdex's car environment for Carla](https://pythonprogramming.net/reinforcement-learning-self-driving-autonomous-cars-carla-python/) into the [basic ARS framework offered by Colin Skow](https://github.com/colinskow/move37/tree/master/ars).

# %%
import datetime
import glob
import os
import sys
import random
import time
import numpy as np
import cv2
import math

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

# Change the directory to where your carla egg file is located to load carla python module
# This should be in the folder you extracted from your Carla download
try:
    sys.path.append(glob.glob('C:\ProgramData\Carla\PythonAPI\carla\dist/carla-*%d.%d-%s.egg' % (
        sys.version_info.major,
        sys.version_info.minor,
        'win-amd64' if os.name == 'nt' else 'linux-x86_64'))[0])
except IndexError:
    pass
import carla

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# If you have GPU-capable tensorflow, the config must be adjusted for the code in this notebook
# to work properly, because of some nebulous error with loading the VGG19 CNN when using the GPU
# Either way, run this cell to make your setup compatible with this process.
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# Skow's Hyperparameter class
class HP():
    # Hyperparameters
    def __init__(self,
                 nb_steps=100,
                 episode_length=2000,
                 learning_rate=0.02,
                 num_deltas=16,
                 num_best_deltas=8,
                 noise=0.03,
                 seed=1,
                 env_name='BipedalWalker-v3',
                 record_every=50):

        self.nb_steps = nb_steps
        self.episode_length = episode_length
        self.learning_rate = learning_rate
        self.num_deltas = num_deltas
        self.num_best_deltas = num_best_deltas
        assert self.num_best_deltas <= self.num_deltas
        self.noise = noise
        self.seed = seed
        self.env_name = env_name
        self.record_every = record_every

# %%
# Skow's Policy class
class Policy():
    def __init__(self, input_size, output_size, hp, theta=None):
        self.input_size = input_size
        self.output_size = output_size
        if theta is not None:
            self.theta = theta
        else:
            #self.theta = np.random.random((output_size, input_size))
            self.theta = np.zeros((output_size, input_size))
        self.hp = hp

    def evaluate(self, input, delta = None, direction = None):
        if direction is None:
            return self.theta.dot(input)
        elif direction == "+":
            return (self.theta + self.hp.noise * delta).dot(input)
        elif direction == "-":
            return (self.theta - self.hp.noise * delta).dot(input)

    def sample_deltas(self):
        return [np.random.randn(*self.theta.shape) for _ in range(self.hp.num_deltas)]
#This code below here is super important 
#This is how the weights are updated according to which configuration of weights led to the biggest reward
    def update(self, rollouts, sigma_rewards):
        # sigma_rewards is the standard deviation of the rewards
        old_theta = self.theta.copy()
        step = np.zeros(self.theta.shape)
        for r_pos, r_neg, delta in rollouts:
            step += (r_pos - r_neg) * delta
        theta_update = self.hp.learning_rate / (self.hp.num_best_deltas * sigma_rewards) * step
        self.theta += theta_update
        if np.array_equal(old_theta, self.theta):
            print("Theta did not change.")

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# %%
# Sentdex's CarEnv class, modified to work in the context of ARS learning
# This required giving it a continuous control scheme for use in a continuous
# action space. The camera input resolution has been changed to 224x224 since
# we will be running it through VGG19 to find edges, and this is the image
# resolution that VGG19 was originally trained on. I have set the number of
# seconds per episode to 15.
# The scoring system has been heavily modified to try and facilitate the learning
# process. Since cars will tend to learn to drive in circles in order to avoid
# collisions, it was necessary to punish driving in circles, and reward driving
# in straighter lines.
class CarEnv:

    def __init__(self, 
                 img_width=224, 
                 img_height=224, 
                 show_cam=False, 
                 control_type='continuous',
                 car_model='mustang',
                 seconds_per_episode=15
                ):
        self.img_width = img_width
        self.img_height = img_height
        self.client = carla.Client("localhost", 2000)
        self.client.set_timeout(5.0)
        self.world = self.client.get_world()
        self.blueprint_library = self.world.get_blueprint_library()
        self.car = self.blueprint_library.filter(car_model)[0]
        self.show_cam = show_cam
        self.control_type = control_type
        self.front_camera = None
        self.actor_list = []
        self.seconds_per_episode = seconds_per_episode
        
        if self.control_type == 'continuous':
            self.action_space = np.array(['throttle', 'steer', 'brake'])

    def reset(self):
        self.collision_hist = []
        self.steering_cache = []
        
        if len(self.actor_list) > 0:
            for actor in self.actor_list:
                actor.destroy()
        self.actor_list = []
        
        try:
            self.transform = random.choice(self.world.get_map().get_spawn_points())
            self.vehicle = self.world.spawn_actor(self.car, self.transform)
            self.actor_list.append(self.vehicle)
        except:
            self.reset()

        # Attach RGB Camera
        self.rgb_cam = self.blueprint_library.find('sensor.camera.rgb')
        self.rgb_cam.set_attribute("image_size_x", f"{self.img_width}")
        self.rgb_cam.set_attribute("image_size_y", f"{self.img_height}")
        self.rgb_cam.set_attribute("fov", f"110")
        
        # This establishes location on the vehicle that the sensor attaches to, we are
        # aiming for the hood in this case.
        transform = carla.Transform(carla.Location(x=2.5, z=0.7))
        self.sensor = self.world.spawn_actor(self.rgb_cam, transform, attach_to=self.vehicle)
        self.actor_list.append(self.sensor)
        self.sensor.listen(lambda data: self.process_img(data))

        self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))
        time.sleep(4)

        # Spawn and attach a collision sensor to the vehicle
        colsensor = self.blueprint_library.find("sensor.other.collision")
        self.colsensor = self.world.spawn_actor(colsensor, transform, attach_to=self.vehicle)
        self.actor_list.append(self.colsensor)
        self.colsensor.listen(lambda event: self.collision_data(event))

        # This loop will wait until the camera is functioning before continuing
        while self.front_camera is None:
            time.sleep(0.01)

        self.episode_start = time.time()
        self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))

        return self.front_camera

    def collision_data(self, event):
        self.collision_hist.append(event)

    def process_img(self, image):
        i = np.array(image.raw_data)
        i2 = i.reshape((self.img_height, self.img_width, 4))
        i3 = i2[:, :, :3]
        if self.show_cam:
            cv2.imshow("", i3)
            cv2.waitKey(1)
        self.front_camera = i3

    def step(self, action, step_num):
        # Continuous action space for use with ARS
        if self.control_type == 'continuous':
            self.vehicle.apply_control(carla.VehicleControl(throttle=np.clip(action[0], 0.0, 1.0), 
                                                            steer=np.clip(action[1], -1.0, 1.0), 
                                                            brake=np.clip(action[2], 0.0, 1.0)))
        # Preserved Sentdex's discrete action space for DQN learning. Not used for ARS
        elif self.control_type == 'action':
            if action == 0:
                self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, 
                                                                steer=-1*self.STEER_AMT))
            elif action == 1:
                self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, steer= 0))
            elif action == 2:
                self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, 
                                                                steer=1*self.STEER_AMT))
        
        # Append current steering control to cache to punish high values. Cleared with reset
        # at start of episode.
        self.steering_cache.append(action[1])
        v = self.vehicle.get_velocity()
        kmh = int(3.6 * math.sqrt(v.x**2 + v.y**2 + v.z**2))

        # Reward System:
        if len(self.collision_hist) != 0:
            # Check to see if on first step (for rough spawns by Carla)
            # Disregards collisions registered on first step of episode
            if step_num == 1:
                self.collision_hist = []
                done = False
                reward = 0
            else:
                done = True
                print('Collision!')
                reward = -200
        elif kmh < 60 & kmh > 0.2:
            done = False
            reward = 1 #-1
            # Reward lighter steering when moving
            if np.abs(action[1]) < 0.3:
                reward += 9
            elif np.abs(action[1]) > 0.5 and np.abs(action[1]) < 0.9:
                reward -= 1
            elif np.abs(action[1]) >= 0.9:
                reward -= 6
        elif kmh <=0.2:
            done = False
            reward = -10
        else:
            done = False
            reward = 20 #2
            # Reward lighter steering when moving
            if np.abs(action[1]) < 0.3:
                reward += 20
            # Reduce score for heavy steering
            if np.abs(action[1]) > 0.5 and np.abs(action[1]) < 0.9:
                reward -= 10
            elif np.abs(action[1]) >= 0.9:
                reward -= 20

        # Penalize consistent and heavily directional steering
        reward -= (np.abs(np.mean(self.steering_cache)) + np.abs(action[1])) * 10 / 2

        # Terminate episode after set number of seconds
        if self.episode_start + self.seconds_per_episode < time.time():
            done = True

        return self.front_camera, reward, done, None

# %%
# Generate a test car
test_car = CarEnv()

# %%
# Generate images for testing VGG19 predictions (kept small for example)
train_images = np.array([test_car.reset().reshape(224, 224, 3) for i in range(1)])

# %%
train_images.shape
# Out:
# (1, 224, 224, 3)

# %%
# An experiment with flattening shapes
train_imgs2 = train_images.reshape(train_images.shape[0], -1)
train_imgs2.shape
# Out:
# (1, 150528)

# %%
# Let's have a look at what our car sees
plt.imshow(train_imgs2[0].reshape(224, 224, 3)/255.)
plt.xticks(())
plt.yticks(());

# %%
# Clean up actors in test_car and clear object from memory
for actor in test_car.actor_list:
    actor.destroy()
del(test_car)

# %%
# We can now pass this image through the VGG19 CNN and observe what the output looks like
# Let's first get an idea of what the model input looks like
base_model = VGG19(weights='imagenet',
                   include_top=False,
                   input_shape=(224,
                                224,
                                3
                               )
                   )
base_model.input_shape
# Out:
# (None, 224, 224, 3)

# %%
# Testing to determine output shape of VGG19
prediction = base_model.predict(train_images[0].reshape(1, 224, 224, 3) / 255.)
prediction.shape
# Out:
# (1, 7, 7, 512)

# %%
# We can see that the CNN has produced 512 7x7 convolutions. Let's look at some
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
for i in range(4):
    col = i % 2
    row = i // 2
    axes[row, col].imshow(prediction[0][:, :, i])

# %%
# While not very meaningful to us humans, these separate 7x7 images represent edge-cases to
# the computer, and may help to generalize unique camera inputs into similar edge-cases
# We will need to flatten this output to make use of the ARS perceptron, let's see what this
# looks like
prediction.flatten().shape
# Out:
# (25088,)

# %%
# For ARS, inputs to the perceptron must be normalized. Usually, this is done by taking rolling
# statistics of the inputs, and using them to perform mean/std filtering to normalize future
# inputs. This allows the algorithm to build these distributions from scratch without needing
# prior information about them. For this context, the outputs of the CNN are going to be on the
# same scale, and just as RGB camera data can be normalized by dividing the pixel values by
# 255, we can similarly normalize the outputs of this CNN by finding out what scale they are on.
# We can do this by creating a histogram of the values within the output.
print('Maximum output value:', np.max(prediction))
print('Minimum output value:', np.min(prediction))

plt.style.use('ggplot')
plt.figure(figsize=(11,7))
plt.title('Distribution of CNN output values')
plt.xlabel('Output Value')
plt.ylabel('Density')
plt.hist(prediction.flatten());
# Out:
# Maximum output value: 10.116544
# Minimum output value: 0.0

# %%
# We can see that these values are occurring on a scale between 0 and 10. This makes
# normalization easy, since all we need to do is divide all of these values by 10, just as
# we would divide RGB camera data by 255.

# %%
# Skow's ARSAgent class, heavily modified to make use of the CarEnv
# initial_train option is experimental, uses train_imgs to train
# some initial weights for the ARS process to start with.
class ARSAgent():
    def __init__(self,
                 hp=None,
                 env=None,
                 base_model=True,
                 policy=None,
                 weights_dir='ars_weights',
                 initial_train=False
                ):

        self.hp = hp or HP()
        np.random.seed(self.hp.seed)
        self.env = env or CarEnv(control_type='continuous')
        self.output_size = self.env.action_space.shape[0]
        self.record_video = False
        self.history = {'step': [],
                        'score': [],
                        'theta': []}
        self.generate_theta = False
        self.historical_steps = 0
        
        if base_model is None:
            self.input_size = self.env.front_camera.shape
        else:
            base_model = VGG19(weights='imagenet', 
                               include_top=False, 
                               input_shape=(self.env.img_height, self.env.img_width,3))
            input_size = 1
            for dim in base_model.output_shape:
                if dim is not None:
                    input_size *= dim
            self.input_size = input_size
            
        if policy is None and initial_train == True:
            self.generate_theta = True
        self.base_model = base_model
        self.policy = policy or Policy(self.input_size, self.output_size, self.hp)
        self.weights_dir = mkdir('', weights_dir)

    # Explore the policy on one specific direction and over one episode
    def explore(self, direction=None, delta=None):
        state = self.env.reset()
        done = False
        sum_rewards = 0.0
        steps = 0
        while not done:
            # Get data from front camera and divide by 255 to normalize
            state = self.env.front_camera.reshape(1, 224, 224, 3) / 255.
            steps += 1
            if self.base_model:
                # Use base model to make prediction, flatten and divide by 10 to normalize
                state = self.base_model.predict(state).flatten() / 10.
            else:
                state = state.flatten()
            action = self.policy.evaluate(state, delta, direction)
            state, reward, done, _ = self.env.step(action, steps)
            #reward = max(min(reward, 1), -1)
            sum_rewards += reward
        print('Worker saw {} steps'.format(steps))
        # Average the rewards per step to account for variable FPS seen by workers
        print('Sum of episode rewards:', sum_rewards)
        adjusted_reward = sum_rewards / steps
        print('Adjusted Reward for episode:', adjusted_reward)
        return adjusted_reward

    def train(self):
        # Experimental. Used to train an initial set of weights for ARS to modify.
        if self.generate_theta:
            print('Training initial weights...')
            pred_model = keras.models.Sequential()
            base_model = VGG19(weights='imagenet', 
                               include_top=False, 
                               input_shape=(224, 224,3))
            for layer in base_model.layers:
                layer.trainable = False
            pred_model.add(base_model)
            pred_model.add(keras.layers.Flatten())
            pred_model.add(Dense(3, input_dim=base_model.output_shape, activation='linear'))
            pred_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
            X = train_imgs.reshape(50, 224, 224, 3)/255.
            y = np.array([1., 0., 0.])
            y = np.tile(y, (50, 1))
            pred_model.fit(X, y, epochs=5, workers=2)
            self.policy.theta = pred_model.get_weights()[-2].T
        
        for step in range(self.hp.nb_steps):
            self.historical_steps += 1
            print('Performing step {}. ({}/{})'.format(self.historical_steps,
                                                       step + 1,
                                                       self.hp.nb_steps
                                                      ))
            start = time.time()
            # Only record video during evaluation, every n steps
            if step % self.hp.record_every == 0:
                self.env.show_cam = True
            # initialize the random noise deltas and the positive/negative rewards
            deltas = self.policy.sample_deltas()
            positive_rewards = [0] * self.hp.num_deltas
            negative_rewards = [0] * self.hp.num_deltas

            # play an episode each with positive deltas and negative deltas, collect rewards
            for k in range(self.hp.num_deltas):
                positive_rewards[k] = self.explore(direction="+", delta=deltas[k])
                negative_rewards[k] = self.explore(direction="-", delta=deltas[k])
                
            # Compute the standard deviation of all rewards
            sigma_rewards = np.array(positive_rewards + negative_rewards).std()

            # Sort the rollouts by the max(r_pos, r_neg) and select the deltas with best rewards
            scores = {k:max(r_pos, r_neg) for k,(r_pos,r_neg) in enumerate(zip(positive_rewards, negative_rewards))}
            order = sorted(scores.keys(), key = lambda x:scores[x], reverse = True)[:self.hp.num_best_deltas]
            rollouts = [(positive_rewards[k], negative_rewards[k], deltas[k]) for k in order]

            # Update the policy
            self.policy.update(rollouts, sigma_rewards)

            if step % self.hp.record_every == 0:
                # Play an episode with the new weights and print the score
                reward_evaluation = self.run_episode()
                print('Step:', step + 1, 'Reward:', reward_evaluation)
                self.history['step'].append(self.historical_steps)
                self.history['score'].append(reward_evaluation)
                self.history['theta'].append(self.policy.theta.copy())
                #self.save()
                
            end = time.time()
            print('Time to complete update step:', end - start)
            self.env.show_cam = False
        
        self.save()

    def save(self):
        save_file = mkdir(self.weights_dir, str(datetime.date.today()))
        np.savetxt(save_file+'/recent_weights.csv'.format(self.historical_steps), 
                   self.policy.theta,
                   delimiter=','
                  )  
            
    def run_episode(self):
        return self.explore()
            
    def clean_up(self):
        for actor in self.env.actor_list:
            actor.destroy()

# %%
# Establish hyperparameters to pass to agent
hp_test = HP(nb_steps=10, 
             noise=0.05, 
             learning_rate=0.02, 
             num_deltas=16, 
             num_best_deltas=8,
             record_every=1
            )

# %%
# Instantiate the agent using these hyperparameters
ars_agent = ARSAgent(hp=hp_test)

# %%
# Load in previously trained weights if you have some
#weights = np.genfromtxt('ars_weights/2020-12-21/recent_weights.csv', delimiter=',')
#ars_agent.policy.theta = weights

# %%
# Train the agent
ars_agent.train()
# Out:
# Performing step 0. (1/10)
# Worker saw 35 steps
# Sum of episode rewards: 71.58280853153826
# Adjusted Reward for episode: 2.0452231009010933
# Worker saw 35 steps
# Sum of episode rewards: -512.8591170562586
# Adjusted Reward for episode: -14.653117630178818
# Worker saw 31 steps
# Sum of episode rewards: -444.8056001426251
# Adjusted Reward for episode: -14.348567746536293
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: 27.76497286428662
# Adjusted Reward for episode: 1.5424984924603677
# Collision!
# Worker saw 31 steps
# Sum of episode rewards: 643.0560612489353
# Adjusted Reward for episode: 20.743743911255976
# Worker saw 36 steps
# Sum of episode rewards: -397.5125345590121
# Adjusted Reward for episode: -11.042014848861449
# Worker saw 35 steps
# Sum of episode rewards: -573.8969614702748
# Adjusted Reward for episode: -16.397056042007854
# Worker saw 36 steps
# Sum of episode rewards: -715.5242673250988
# Adjusted Reward for episode: -19.875674092363855
# Worker saw 37 steps
# Sum of episode rewards: -389.9673082408855
# Adjusted Reward for episode: -10.539656979483391
# Worker saw 35 steps
# Sum of episode rewards: -368.89847310874416
# Adjusted Reward for episode: -10.539956374535548
# Worker saw 36 steps
# Sum of episode rewards: 1059.690032600287
# Adjusted Reward for episode: 29.43583423889686
# Worker saw 37 steps
# Sum of episode rewards: -467.0123983938919
# Adjusted Reward for episode: -12.62195671334843
# Worker saw 37 steps
# Sum of episode rewards: -397.365341375013
# Adjusted Reward for episode: -10.739603820946297
# Worker saw 36 steps
# Sum of episode rewards: -404.88592642570734
# Adjusted Reward for episode: -11.246831289602982
# Worker saw 35 steps
# Sum of episode rewards: -427.65892119859865
# Adjusted Reward for episode: -12.21882631995996
# Worker saw 36 steps
# Sum of episode rewards: -266.5389029913918
# Adjusted Reward for episode: -7.40385841642755
# Worker saw 36 steps
# Sum of episode rewards: -436.03195675788214
# Adjusted Reward for episode: -12.11199879883006
# Worker saw 36 steps
# Sum of episode rewards: -428.2869299094376
# Adjusted Reward for episode: -11.896859164151046
# Worker saw 36 steps
# Sum of episode rewards: -412.4291340761101
# Adjusted Reward for episode: -11.456364835447502
# Worker saw 35 steps
# Sum of episode rewards: -369.71467302155474
# Adjusted Reward for episode: -10.563276372044422
# Collision!
# Worker saw 21 steps
# Sum of episode rewards: 4.419399053512166
# Adjusted Reward for episode: 0.2104475739767698
# Worker saw 35 steps
# Sum of episode rewards: -415.99007774835235
# Adjusted Reward for episode: -11.885430792810068
# Worker saw 35 steps
# Sum of episode rewards: -457.9876509779361
# Adjusted Reward for episode: -13.085361456512459
# Worker saw 36 steps
# Sum of episode rewards: -461.34025449877754
# Adjusted Reward for episode: -12.815007069410488
# Worker saw 37 steps
# Sum of episode rewards: -541.0613869569073
# Adjusted Reward for episode: -14.623280728565062
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -69.97487897720612
# Adjusted Reward for episode: -4.998205641229008
# Worker saw 36 steps
# Sum of episode rewards: -726.3009717288807
# Adjusted Reward for episode: -20.175026992468908
# Worker saw 36 steps
# Sum of episode rewards: -619.2086440574484
# Adjusted Reward for episode: -17.2002401127069
# Collision!
# Worker saw 32 steps
# Sum of episode rewards: 570.326044129554
# Adjusted Reward for episode: 17.822688879048563
# Worker saw 38 steps
# Sum of episode rewards: -435.16288431404166
# Adjusted Reward for episode: -11.451654850369517
# Worker saw 33 steps
# Sum of episode rewards: 164.49596598942676
# Adjusted Reward for episode: 4.984726242103841
# Worker saw 33 steps
# Sum of episode rewards: -404.4783964798274
# Adjusted Reward for episode: -12.256921105449315
# Worker saw 34 steps
# Sum of episode rewards: 953.3511341724549
# Adjusted Reward for episode: 28.03973924036632
# Step: 1 Reward: 28.03973924036632
# Time to complete update step: 638.4755463600159
# Performing step 1. (2/10)
# Worker saw 36 steps
# Sum of episode rewards: 946.9234471347153
# Adjusted Reward for episode: 26.303429087075425
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: 196.0382457371677
# Adjusted Reward for episode: 10.317802407219352
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: -122.93740897272626
# Adjusted Reward for episode: -6.829856054040348
# Worker saw 35 steps
# Sum of episode rewards: -503.6609898829114
# Adjusted Reward for episode: -14.390313996654612
# Worker saw 35 steps
# Sum of episode rewards: -492.9241174126714
# Adjusted Reward for episode: -14.083546211790612
# Worker saw 37 steps
# Sum of episode rewards: -381.7955498763783
# Adjusted Reward for episode: -10.31879864530752
# Worker saw 36 steps
# Sum of episode rewards: -454.34837270164184
# Adjusted Reward for episode: -12.620788130601163
# Worker saw 37 steps
# Sum of episode rewards: 1071.4788881578934
# Adjusted Reward for episode: 28.958888869132252
# Worker saw 36 steps
# Sum of episode rewards: -457.7615288117818
# Adjusted Reward for episode: -12.715598022549493
# Worker saw 37 steps
# Sum of episode rewards: 1088.9826159545253
# Adjusted Reward for episode: 29.431962593365547
# Worker saw 34 steps
# Sum of episode rewards: -426.16550459208327
# Adjusted Reward for episode: -12.534279546825978
# Worker saw 37 steps
# Sum of episode rewards: 1027.8448478662372
# Adjusted Reward for episode: 27.779590482871274
# Worker saw 35 steps
# Sum of episode rewards: -389.85705243512416
# Adjusted Reward for episode: -11.138772926717833
# Collision!
# Worker saw 29 steps
# Sum of episode rewards: 519.9773730769778
# Adjusted Reward for episode: 17.930254244033716
# Worker saw 37 steps
# Sum of episode rewards: -476.6589017237352
# Adjusted Reward for episode: -12.88267301956041
# Worker saw 37 steps
# Sum of episode rewards: 629.6013936858232
# Adjusted Reward for episode: 17.016253883400626
# Worker saw 36 steps
# Sum of episode rewards: -368.75106135180357
# Adjusted Reward for episode: -10.243085037550099
# Worker saw 37 steps
# Sum of episode rewards: -164.41065306466066
# Adjusted Reward for episode: -4.443531163909748
# Worker saw 37 steps
# Sum of episode rewards: -477.82906353228645
# Adjusted Reward for episode: -12.91429901438612
# Worker saw 37 steps
# Sum of episode rewards: -384.3755886644653
# Adjusted Reward for episode: -10.388529423363927
# Worker saw 37 steps
# Sum of episode rewards: -541.0619509653734
# Adjusted Reward for episode: -14.623295972037118
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: -137.149543292647
# Adjusted Reward for episode: -7.2183970154024735
# Worker saw 36 steps
# Sum of episode rewards: -397.52346375778603
# Adjusted Reward for episode: -11.042318437716279
# Collision!
# Worker saw 27 steps
# Sum of episode rewards: 289.44197771442634
# Adjusted Reward for episode: 10.720073248682457
# Worker saw 37 steps
# Sum of episode rewards: 1103.615012708566
# Adjusted Reward for episode: 29.827432775907187
# Worker saw 37 steps
# Sum of episode rewards: -135.8229615268013
# Adjusted Reward for episode: -3.6708908520757104
# Worker saw 37 steps
# Sum of episode rewards: 897.0837213020205
# Adjusted Reward for episode: 24.24550598113569
# Worker saw 37 steps
# Sum of episode rewards: -433.8658540582652
# Adjusted Reward for episode: -11.726104163736897
# Worker saw 36 steps
# Sum of episode rewards: -241.20988872326626
# Adjusted Reward for episode: -6.700274686757396
# Worker saw 37 steps
# Sum of episode rewards: -675.146746322368
# Adjusted Reward for episode: -18.247209360064
# Worker saw 37 steps
# Sum of episode rewards: -478.3288297317161
# Adjusted Reward for episode: -12.9278062089653
# Worker saw 36 steps
# Sum of episode rewards: -362.08967722813793
# Adjusted Reward for episode: -10.058046589670498
# Collision!
# Worker saw 29 steps
# Sum of episode rewards: 596.7220479684358
# Adjusted Reward for episode: 20.576622343739167
# Step: 2 Reward: 20.576622343739167
# Time to complete update step: 635.3587529659271
# Performing step 2. (3/10)
# Worker saw 36 steps
# Sum of episode rewards: -598.3624787451579
# Adjusted Reward for episode: -16.621179965143273
# Worker saw 36 steps
# Sum of episode rewards: -583.1928513940887
# Adjusted Reward for episode: -16.199801427613576
# Worker saw 37 steps
# Sum of episode rewards: -447.0138429330558
# Adjusted Reward for episode: -12.081455214406914
# Collision!
# Worker saw 23 steps
# Sum of episode rewards: 320.78233386454116
# Adjusted Reward for episode: 13.947057994110486
# Worker saw 36 steps
# Sum of episode rewards: -450.0406690242956
# Adjusted Reward for episode: -12.501129695119323
# Collision!
# Worker saw 27 steps
# Sum of episode rewards: 418.18184498797564
# Adjusted Reward for episode: 15.488216481036135
# Worker saw 35 steps
# Sum of episode rewards: -39.95538537566685
# Adjusted Reward for episode: -1.141582439304767
# Collision!
# Worker saw 12 steps
# Sum of episode rewards: -288.52254658847835
# Adjusted Reward for episode: -24.043545549039862
# Worker saw 36 steps
# Sum of episode rewards: -538.5535985418916
# Adjusted Reward for episode: -14.959822181719211
# Worker saw 35 steps
# Sum of episode rewards: -782.503814356316
# Adjusted Reward for episode: -22.357251838751885
# Collision!
# Worker saw 32 steps
# Sum of episode rewards: 488.8031995590058
# Adjusted Reward for episode: 15.275099986218931
# Collision!
# Worker saw 28 steps
# Sum of episode rewards: 499.7719551136703
# Adjusted Reward for episode: 17.848998396916794
# Collision!
# Worker saw 34 steps
# Sum of episode rewards: -47.5549635833338
# Adjusted Reward for episode: -1.3986753995098178
# Collision!
# Worker saw 36 steps
# Sum of episode rewards: 576.106943705854
# Adjusted Reward for episode: 16.002970658495943
# Worker saw 34 steps
# Sum of episode rewards: -533.5639547952727
# Adjusted Reward for episode: -15.693057493978609
# Worker saw 35 steps
# Sum of episode rewards: -505.0881216969184
# Adjusted Reward for episode: -14.431089191340526
# Collision!
# Worker saw 28 steps
# Sum of episode rewards: 449.21807370394185
# Adjusted Reward for episode: 16.043502632283637
# Worker saw 34 steps
# Sum of episode rewards: -393.2507907429463
# Adjusted Reward for episode: -11.566199727733716
# Worker saw 36 steps
# Sum of episode rewards: 493.5949829721471
# Adjusted Reward for episode: 13.710971749226308
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: 17.658429492642
# Adjusted Reward for episode: 1.103651843290125
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -204.87143775115106
# Adjusted Reward for episode: -15.759341365473158
# Worker saw 35 steps
# Sum of episode rewards: -547.7606062020254
# Adjusted Reward for episode: -15.650303034343583
# Worker saw 36 steps
# Sum of episode rewards: -624.0071868292271
# Adjusted Reward for episode: -17.33353296747853
# Collision!
# Worker saw 21 steps
# Sum of episode rewards: 15.756804448254144
# Adjusted Reward for episode: 0.7503240213454354
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 249.29342332941414
# Adjusted Reward for episode: 12.464671166470707
# Worker saw 36 steps
# Sum of episode rewards: 820.2275929062088
# Adjusted Reward for episode: 22.784099802950244
# Worker saw 36 steps
# Sum of episode rewards: -409.48652838778816
# Adjusted Reward for episode: -11.374625788549672
# Worker saw 36 steps
# Sum of episode rewards: -364.4042589623262
# Adjusted Reward for episode: -10.122340526731284
# Worker saw 37 steps
# Sum of episode rewards: -433.3924160046154
# Adjusted Reward for episode: -11.713308540665281
# Worker saw 38 steps
# Sum of episode rewards: 1197.620951595498
# Adjusted Reward for episode: 31.51634083146047
# Worker saw 35 steps
# Sum of episode rewards: -406.95787020589165
# Adjusted Reward for episode: -11.627367720168333
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 247.39167467336216
# Adjusted Reward for episode: 10.307986444723424
# Collision!
# Worker saw 33 steps
# Sum of episode rewards: 769.4065686755549
# Adjusted Reward for episode: 23.315350565925907
# Step: 3 Reward: 23.315350565925907
# Time to complete update step: 601.1528842449188
# Performing step 3. (4/10)
# Worker saw 36 steps
# Sum of episode rewards: -118.66370552324524
# Adjusted Reward for episode: -3.296214042312368
# Worker saw 35 steps
# Sum of episode rewards: -543.8258821381754
# Adjusted Reward for episode: -15.537882346805011
# Worker saw 34 steps
# Sum of episode rewards: 1021.2388285063773
# Adjusted Reward for episode: 30.03643613254051
# Collision!
# Worker saw 21 steps
# Sum of episode rewards: 203.54738996143422
# Adjusted Reward for episode: 9.692732855306392
# Collision!
# Worker saw 23 steps
# Sum of episode rewards: 219.82500763308087
# Adjusted Reward for episode: 9.557609027525256
# Worker saw 36 steps
# Sum of episode rewards: -416.7355884974186
# Adjusted Reward for episode: -11.575988569372738
# Worker saw 37 steps
# Sum of episode rewards: -456.5243920041786
# Adjusted Reward for episode: -12.338497081194015
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: 98.75370872151558
# Adjusted Reward for episode: 5.197563616921872
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -11.16226229020674
# Adjusted Reward for episode: -0.7973044493004815
# Worker saw 37 steps
# Sum of episode rewards: -425.75750004584586
# Adjusted Reward for episode: -11.506959460698537
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -73.47039619831546
# Adjusted Reward for episode: -5.651568938331958
# Worker saw 34 steps
# Sum of episode rewards: 935.0595817860816
# Adjusted Reward for episode: 27.50175240547299
# Worker saw 35 steps
# Sum of episode rewards: 785.9081363092461
# Adjusted Reward for episode: 22.454518180264174
# Worker saw 35 steps
# Sum of episode rewards: -539.1812003914082
# Adjusted Reward for episode: -15.405177154040235
# Worker saw 34 steps
# Sum of episode rewards: -423.0582229616841
# Adjusted Reward for episode: -12.442888910637768
# Collision!
# Worker saw 23 steps
# Sum of episode rewards: 366.2443723804695
# Adjusted Reward for episode: 15.923668364368238
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: -26.649205449600345
# Adjusted Reward for episode: -1.4805114138666857
# Collision!
# Worker saw 32 steps
# Sum of episode rewards: 143.6299276048935
# Adjusted Reward for episode: 4.488435237652922
# Collision!
# Worker saw 10 steps
# Sum of episode rewards: -281.63098489547974
# Adjusted Reward for episode: -28.163098489547973
# Worker saw 35 steps
# Sum of episode rewards: -510.3267455620411
# Adjusted Reward for episode: -14.580764158915459
# Collision!
# Worker saw 21 steps
# Sum of episode rewards: -50.02528864884616
# Adjusted Reward for episode: -2.3821566023260075
# Worker saw 33 steps
# Sum of episode rewards: -423.0118831515479
# Adjusted Reward for episode: -12.818541913683271
# Collision!
# Worker saw 30 steps
# Sum of episode rewards: 497.3421730018774
# Adjusted Reward for episode: 16.578072433395914
# Collision!
# Worker saw 22 steps
# Sum of episode rewards: 256.2911035102333
# Adjusted Reward for episode: 11.649595614101514
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -0.04182051487052263
# Adjusted Reward for episode: -0.002987179633608759
# Worker saw 35 steps
# Sum of episode rewards: 1039.1575503624829
# Adjusted Reward for episode: 29.690215724642368
# Worker saw 35 steps
# Sum of episode rewards: -705.2242221347583
# Adjusted Reward for episode: -20.14926348956452
# Collision!
# Worker saw 12 steps
# Sum of episode rewards: -397.69827989798773
# Adjusted Reward for episode: -33.14152332483231
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -272.7740297625599
# Adjusted Reward for episode: -19.48385926875428
# Worker saw 34 steps
# Sum of episode rewards: -17.6846924303354
# Adjusted Reward for episode: -0.5201380126569235
# Worker saw 33 steps
# Sum of episode rewards: 508.0897541172495
# Adjusted Reward for episode: 15.396659215674228
# Worker saw 34 steps
# Sum of episode rewards: 424.66807408935347
# Adjusted Reward for episode: 12.490237473216279
# Worker saw 34 steps
# Sum of episode rewards: 951.5681634242837
# Adjusted Reward for episode: 27.98729892424364
# Step: 4 Reward: 27.98729892424364
# Time to complete update step: 559.2609941959381
# Performing step 4. (5/10)
# Worker saw 33 steps
# Sum of episode rewards: -368.44789241720053
# Adjusted Reward for episode: -11.165087649006077
# Collision!
# Worker saw 25 steps
# Sum of episode rewards: 376.4696412916759
# Adjusted Reward for episode: 15.058785651667035
# Worker saw 33 steps
# Sum of episode rewards: -189.3078257158157
# Adjusted Reward for episode: -5.7366007792671425
# Worker saw 35 steps
# Sum of episode rewards: -257.37600185898765
# Adjusted Reward for episode: -7.353600053113933
# Worker saw 34 steps
# Sum of episode rewards: -457.60372660960525
# Adjusted Reward for episode: -13.458933135576626
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 194.17781605097798
# Adjusted Reward for episode: 9.708890802548899
# Collision!
# Worker saw 28 steps
# Sum of episode rewards: 452.57154424079357
# Adjusted Reward for episode: 16.1632694371712
# Worker saw 34 steps
# Sum of episode rewards: 1038.1039909346725
# Adjusted Reward for episode: 30.532470321608017
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 329.94173129324327
# Adjusted Reward for episode: 13.74757213721847
# Collision!
# Worker saw 29 steps
# Sum of episode rewards: 455.9533647924984
# Adjusted Reward for episode: 15.72252982043098
# Collision!
# Worker saw 15 steps
# Sum of episode rewards: -185.53483510056313
# Adjusted Reward for episode: -12.368989006704208
# Collision!
# Worker saw 27 steps
# Sum of episode rewards: 507.1041613241785
# Adjusted Reward for episode: 18.781635604599202
# Collision!
# Worker saw 34 steps
# Sum of episode rewards: 189.3633181957017
# Adjusted Reward for episode: 5.569509358697109
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: -141.85377984793575
# Adjusted Reward for episode: -8.865861240495985
# Worker saw 35 steps
# Sum of episode rewards: 1004.4375986782013
# Adjusted Reward for episode: 28.698217105091466
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: 52.23618326788599
# Adjusted Reward for episode: 3.2647614542428744
# Worker saw 37 steps
# Sum of episode rewards: -387.58606236199887
# Adjusted Reward for episode: -10.475298982756726
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: -45.445417679537655
# Adjusted Reward for episode: -2.8403386049711035
# Collision!
# Worker saw 15 steps
# Sum of episode rewards: -91.73812914282436
# Adjusted Reward for episode: -6.115875276188291
# Worker saw 33 steps
# Sum of episode rewards: 663.1485416947614
# Adjusted Reward for episode: 20.09541035438671
# Worker saw 35 steps
# Sum of episode rewards: 196.1712150798546
# Adjusted Reward for episode: 5.604891859424417
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -324.6033032468381
# Adjusted Reward for episode: -24.969484865141393
# Worker saw 36 steps
# Sum of episode rewards: 812.2779988416603
# Adjusted Reward for episode: 22.563277745601674
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: -19.79187625726894
# Adjusted Reward for episode: -1.0416776977509967
# Worker saw 36 steps
# Sum of episode rewards: 279.8793497347142
# Adjusted Reward for episode: 7.774426381519839
# Collision!
# Worker saw 29 steps
# Sum of episode rewards: -8.873874476701303
# Adjusted Reward for episode: -0.30599567161038976
# Worker saw 37 steps
# Sum of episode rewards: -107.50933950462043
# Adjusted Reward for episode: -2.9056578244492006
# Collision!
# Worker saw 12 steps
# Sum of episode rewards: -232.76373971764275
# Adjusted Reward for episode: -19.39697830980356
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -144.44571877626987
# Adjusted Reward for episode: -11.111209136636145
# Worker saw 36 steps
# Sum of episode rewards: 653.3005606505986
# Adjusted Reward for episode: 18.14723779584996
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: 79.55053871372553
# Adjusted Reward for episode: 4.6794434537485605
# Worker saw 34 steps
# Sum of episode rewards: -394.9723218057359
# Adjusted Reward for episode: -11.61683299428635
# Collision!
# Worker saw 35 steps
# Sum of episode rewards: 774.4629114305038
# Adjusted Reward for episode: 22.12751175515725
# Step: 5 Reward: 22.12751175515725
# Time to complete update step: 552.5175206661224
# Performing step 5. (6/10)
# Worker saw 37 steps
# Sum of episode rewards: -464.2703329538311
# Adjusted Reward for episode: -12.547846836590029
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: 67.4783482213345
# Adjusted Reward for episode: 4.217396763833406
# Collision!
# Worker saw 12 steps
# Sum of episode rewards: -168.27983982627444
# Adjusted Reward for episode: -14.02331998552287
# Worker saw 36 steps
# Sum of episode rewards: 649.9751644939184
# Adjusted Reward for episode: 18.054865680386623
# Worker saw 36 steps
# Sum of episode rewards: -388.7044421205262
# Adjusted Reward for episode: -10.797345614459061
# Worker saw 36 steps
# Sum of episode rewards: -191.71747894699692
# Adjusted Reward for episode: -5.32548552630547
# Worker saw 36 steps
# Sum of episode rewards: -467.5874728320318
# Adjusted Reward for episode: -12.988540912000882
# Worker saw 37 steps
# Sum of episode rewards: 1092.9126023823296
# Adjusted Reward for episode: 29.538178442765666
# Collision!
# Worker saw 12 steps
# Sum of episode rewards: -83.87445501727345
# Adjusted Reward for episode: -6.98953791810612
# Worker saw 37 steps
# Sum of episode rewards: 1034.370691287429
# Adjusted Reward for episode: 27.955964629389975
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: -42.42222649571883
# Adjusted Reward for episode: -2.23274876293257
# Worker saw 37 steps
# Sum of episode rewards: 1071.88743522464
# Adjusted Reward for episode: 28.96993068174703
# Worker saw 37 steps
# Sum of episode rewards: 1089.3676564479854
# Adjusted Reward for episode: 29.442369093188795
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 354.4888995019023
# Adjusted Reward for episode: 14.770370812579264
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -236.6262378579665
# Adjusted Reward for episode: -16.901874132711892
# Worker saw 37 steps
# Sum of episode rewards: -214.77359779935335
# Adjusted Reward for episode: -5.804691832414956
# Worker saw 37 steps
# Sum of episode rewards: -504.1901680177736
# Adjusted Reward for episode: -13.626761297777666
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 246.22121354048426
# Adjusted Reward for episode: 12.311060677024212
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: 2.9224007129464837
# Adjusted Reward for episode: 0.16235559516369355
# Worker saw 37 steps
# Sum of episode rewards: 96.89009506228996
# Adjusted Reward for episode: 2.6186512178997288
# Collision!
# Worker saw 22 steps
# Sum of episode rewards: 256.72098982031025
# Adjusted Reward for episode: 11.669135900923193
# Collision!
# Worker saw 23 steps
# Sum of episode rewards: 203.78733265518943
# Adjusted Reward for episode: 8.860318811095192
# Worker saw 37 steps
# Sum of episode rewards: 1056.266745109457
# Adjusted Reward for episode: 28.54774986782316
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -193.07670235632645
# Adjusted Reward for episode: -11.357453079783909
# Worker saw 36 steps
# Sum of episode rewards: 95.58347331441892
# Adjusted Reward for episode: 2.655096480956081
# Worker saw 37 steps
# Sum of episode rewards: -432.31571856465564
# Adjusted Reward for episode: -11.684208609855558
# Collision!
# Worker saw 25 steps
# Sum of episode rewards: 482.3359410399107
# Adjusted Reward for episode: 19.29343764159643
# Collision!
# Worker saw 22 steps
# Sum of episode rewards: 186.75821864674504
# Adjusted Reward for episode: 8.48900993848841
# Worker saw 36 steps
# Sum of episode rewards: 953.517527455032
# Adjusted Reward for episode: 26.486597984862
# Worker saw 37 steps
# Sum of episode rewards: 200.66743928456845
# Adjusted Reward for episode: 5.423444304988337
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -141.99390702870048
# Adjusted Reward for episode: -10.922608232976959
# Collision!
# Worker saw 26 steps
# Sum of episode rewards: 427.23262097691355
# Adjusted Reward for episode: 16.432023883727446
# Worker saw 36 steps
# Sum of episode rewards: 1065.9585644501017
# Adjusted Reward for episode: 29.609960123613934
# Step: 6 Reward: 29.609960123613934
# Time to complete update step: 555.1173319816589
# Performing step 6. (7/10)
# Collision!
# Worker saw 32 steps
# Sum of episode rewards: 488.2315128339363
# Adjusted Reward for episode: 15.257234776060509
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 146.51778744678813
# Adjusted Reward for episode: 7.3258893723394065
# Collision!
# Worker saw 29 steps
# Sum of episode rewards: 382.58228700347263
# Adjusted Reward for episode: 13.19249265529216
# Worker saw 37 steps
# Sum of episode rewards: 287.5398678191205
# Adjusted Reward for episode: 7.771347778895149
# Worker saw 37 steps
# Sum of episode rewards: -576.8232091651415
# Adjusted Reward for episode: -15.589816463922745
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: 84.08786938359816
# Adjusted Reward for episode: 4.671548299088787
# Worker saw 36 steps
# Sum of episode rewards: 943.217454199719
# Adjusted Reward for episode: 26.20048483888108
# Collision!
# Worker saw 28 steps
# Sum of episode rewards: 538.0332521116302
# Adjusted Reward for episode: 19.215473289701077
# Collision!
# Worker saw 26 steps
# Sum of episode rewards: 146.4884217219071
# Adjusted Reward for episode: 5.634170066227195
# Worker saw 37 steps
# Sum of episode rewards: 754.5408115149522
# Adjusted Reward for episode: 20.39299490580952
# Collision!
# Worker saw 15 steps
# Sum of episode rewards: -85.87131294628777
# Adjusted Reward for episode: -5.724754196419185
# Worker saw 37 steps
# Sum of episode rewards: -658.9505351307006
# Adjusted Reward for episode: -17.809473922451367
# Worker saw 37 steps
# Sum of episode rewards: -400.61393722448383
# Adjusted Reward for episode: -10.827403708769832
# Collision!
# Worker saw 23 steps
# Sum of episode rewards: 363.3928765978414
# Adjusted Reward for episode: 15.799690286862669
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -104.48671615593312
# Adjusted Reward for episode: -7.463336868280938
# Worker saw 37 steps
# Sum of episode rewards: -55.095794273185284
# Adjusted Reward for episode: -1.4890755208968995
# Collision!
# Worker saw 25 steps
# Sum of episode rewards: 201.1682845504991
# Adjusted Reward for episode: 8.046731382019964
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -72.79763219486023
# Adjusted Reward for episode: -4.28221365852119
# Collision!
# Worker saw 25 steps
# Sum of episode rewards: 322.5011685736824
# Adjusted Reward for episode: 12.900046742947294
# Collision!
# Worker saw 28 steps
# Sum of episode rewards: 451.0406728058904
# Adjusted Reward for episode: 16.10859545735323
# Worker saw 37 steps
# Sum of episode rewards: -406.3342305138594
# Adjusted Reward for episode: -10.982006230104307
# Collision!
# Worker saw 15 steps
# Sum of episode rewards: -144.46825149037326
# Adjusted Reward for episode: -9.631216766024885
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: -44.19421518719096
# Adjusted Reward for episode: -2.762138449199435
# Worker saw 37 steps
# Sum of episode rewards: -409.6978380728384
# Adjusted Reward for episode: -11.072914542509146
# Worker saw 36 steps
# Sum of episode rewards: -509.4097665692669
# Adjusted Reward for episode: -14.150271293590746
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: -104.67246408737054
# Adjusted Reward for episode: -6.542029005460659
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: -220.52741120783742
# Adjusted Reward for episode: -12.251522844879856
# Worker saw 36 steps
# Sum of episode rewards: -500.6371348369201
# Adjusted Reward for episode: -13.906587078803335
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: 73.63087621135838
# Adjusted Reward for episode: 4.0906042339643545
# Worker saw 37 steps
# Sum of episode rewards: 830.502737869182
# Adjusted Reward for episode: 22.446019942410327
# Worker saw 37 steps
# Sum of episode rewards: 303.42047198887485
# Adjusted Reward for episode: 8.200553296996617
# Collision!
# Worker saw 32 steps
# Sum of episode rewards: 871.3582451183663
# Adjusted Reward for episode: 27.229945159948947
# Collision!
# Worker saw 27 steps
# Sum of episode rewards: 499.00616608105884
# Adjusted Reward for episode: 18.48170985485403
# Step: 7 Reward: 18.48170985485403
# Time to complete update step: 544.4123523235321
# Performing step 7. (8/10)
# Worker saw 36 steps
# Sum of episode rewards: 982.5225427026735
# Adjusted Reward for episode: 27.292292852852043
# Collision!
# Worker saw 34 steps
# Sum of episode rewards: 412.02371239079
# Adjusted Reward for episode: 12.11834448208206
# Collision!
# Worker saw 28 steps
# Sum of episode rewards: -106.23089787830523
# Adjusted Reward for episode: -3.793960638510901
# Worker saw 37 steps
# Sum of episode rewards: -458.5720291243327
# Adjusted Reward for episode: -12.393838624981964
# Worker saw 37 steps
# Sum of episode rewards: 435.1247706400851
# Adjusted Reward for episode: 11.760128936218516
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 269.09838757667467
# Adjusted Reward for episode: 11.212432815694777
# Collision!
# Worker saw 12 steps
# Sum of episode rewards: -273.304412046056
# Adjusted Reward for episode: -22.775367670504664
# Worker saw 36 steps
# Sum of episode rewards: -730.713455609496
# Adjusted Reward for episode: -20.29759598915267
# Worker saw 36 steps
# Sum of episode rewards: -371.7274144734018
# Adjusted Reward for episode: -10.325761513150049
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: 140.02329228397008
# Adjusted Reward for episode: 7.3696469623142145
# Worker saw 36 steps
# Sum of episode rewards: 929.1511951411569
# Adjusted Reward for episode: 25.809755420587692
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: 49.30198758059723
# Adjusted Reward for episode: 2.9001169165057195
# Worker saw 37 steps
# Sum of episode rewards: -449.2790259562921
# Adjusted Reward for episode: -12.142676377197084
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: 79.62461269990894
# Adjusted Reward for episode: 4.190769089468891
# Worker saw 37 steps
# Sum of episode rewards: -530.7767846768031
# Adjusted Reward for episode: -14.345318504778463
# Collision!
# Worker saw 18 steps
# Sum of episode rewards: -45.31238683080994
# Adjusted Reward for episode: -2.5173548239338857
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 256.3448866467549
# Adjusted Reward for episode: 12.817244332337745
# Worker saw 37 steps
# Sum of episode rewards: 903.9423433699089
# Adjusted Reward for episode: 24.430874145132673
# Worker saw 37 steps
# Sum of episode rewards: -573.0479489631122
# Adjusted Reward for episode: -15.487782404408437
# Collision!
# Worker saw 30 steps
# Sum of episode rewards: 481.93219778227126
# Adjusted Reward for episode: 16.064406592742376
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -174.28959545572627
# Adjusted Reward for episode: -10.252329144454487
# Worker saw 34 steps
# Sum of episode rewards: -482.4464134796394
# Adjusted Reward for episode: -14.189600396459982
# Worker saw 35 steps
# Sum of episode rewards: -360.81414505913466
# Adjusted Reward for episode: -10.308975573118133
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 356.0207548834965
# Adjusted Reward for episode: 14.834198120145688
# Worker saw 36 steps
# Sum of episode rewards: 341.7126325621335
# Adjusted Reward for episode: 9.492017571170374
# Worker saw 37 steps
# Sum of episode rewards: 701.2254726074041
# Adjusted Reward for episode: 18.95203980020011
# Worker saw 36 steps
# Sum of episode rewards: 493.54969150217335
# Adjusted Reward for episode: 13.709713652838149
# Collision!
# Worker saw 22 steps
# Sum of episode rewards: 198.80066940277754
# Adjusted Reward for episode: 9.036394063762616
# Worker saw 36 steps
# Sum of episode rewards: -563.4450708651029
# Adjusted Reward for episode: -15.651251968475082
# Worker saw 36 steps
# Sum of episode rewards: -3.6743078491400247
# Adjusted Reward for episode: -0.10206410692055624
# Worker saw 37 steps
# Sum of episode rewards: 180.37394512770737
# Adjusted Reward for episode: 4.874971489938037
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -38.19781618747086
# Adjusted Reward for episode: -2.2469303639688745
# Collision!
# Worker saw 30 steps
# Sum of episode rewards: 571.3160791072244
# Adjusted Reward for episode: 19.043869303574144
# Step: 8 Reward: 19.043869303574144
# Time to complete update step: 588.4786295890808
# Performing step 8. (9/10)
# Worker saw 33 steps
# Sum of episode rewards: 959.1900991091794
# Adjusted Reward for episode: 29.066366639672104
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: 78.89137755906438
# Adjusted Reward for episode: 4.930711097441524
# Collision!
# Worker saw 33 steps
# Sum of episode rewards: 740.4098970973198
# Adjusted Reward for episode: 22.43666354840363
# Collision!
# Worker saw 26 steps
# Sum of episode rewards: 456.5912926537194
# Adjusted Reward for episode: 17.561203563604593
# Worker saw 37 steps
# Sum of episode rewards: -146.2090849103057
# Adjusted Reward for episode: -3.9515968894677216
# Worker saw 37 steps
# Sum of episode rewards: -59.827486841886255
# Adjusted Reward for episode: -1.6169591038347637
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -309.96122489262905
# Adjusted Reward for episode: -18.23301322897818
# Worker saw 37 steps
# Sum of episode rewards: -310.317800549893
# Adjusted Reward for episode: -8.38696758242954
# Collision!
# Worker saw 35 steps
# Sum of episode rewards: 44.992194831920756
# Adjusted Reward for episode: 1.2854912809120216
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: -206.13981705636516
# Adjusted Reward for episode: -12.883738566022823
# Collision!
# Worker saw 34 steps
# Sum of episode rewards: 686.2432845100955
# Adjusted Reward for episode: 20.183626015002808
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 247.22185255453522
# Adjusted Reward for episode: 10.300910523105633
# Collision!
# Worker saw 22 steps
# Sum of episode rewards: 224.65228107398852
# Adjusted Reward for episode: 10.211467321544932
# Worker saw 37 steps
# Sum of episode rewards: 68.32183284457837
# Adjusted Reward for episode: 1.8465360228264422
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -198.1629037005566
# Adjusted Reward for episode: -11.656641394150387
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: -236.20797127834302
# Adjusted Reward for episode: -13.894586545784884
# Collision!
# Worker saw 27 steps
# Sum of episode rewards: 530.7641922932246
# Adjusted Reward for episode: 19.657933047897206
# Worker saw 36 steps
# Sum of episode rewards: -475.92564777962406
# Adjusted Reward for episode: -13.220156882767334
# Collision!
# Worker saw 32 steps
# Sum of episode rewards: -18.333401343206532
# Adjusted Reward for episode: -0.5729187919752041
# Collision!
# Worker saw 19 steps
# Sum of episode rewards: 166.89866080086685
# Adjusted Reward for episode: 8.784140042150886
# Collision!
# Worker saw 37 steps
# Sum of episode rewards: 717.6389934230411
# Adjusted Reward for episode: 19.395648470893004
# Worker saw 37 steps
# Sum of episode rewards: 156.26944043953273
# Adjusted Reward for episode: 4.2234983902576415
# Collision!
# Worker saw 31 steps
# Sum of episode rewards: 574.8574612828062
# Adjusted Reward for episode: 18.54378907363891
# Collision!
# Worker saw 25 steps
# Sum of episode rewards: 149.45755462129424
# Adjusted Reward for episode: 5.97830218485177
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 401.04673682363455
# Adjusted Reward for episode: 16.71028070098477
# Worker saw 37 steps
# Sum of episode rewards: 760.6372003908086
# Adjusted Reward for episode: 20.55776217272456
# Worker saw 32 steps
# Sum of episode rewards: 406.10412207418955
# Adjusted Reward for episode: 12.690753814818423
# Worker saw 36 steps
# Sum of episode rewards: -433.5355582616009
# Adjusted Reward for episode: -12.04265439615558
# Worker saw 32 steps
# Sum of episode rewards: -390.28322615699733
# Adjusted Reward for episode: -12.196350817406167
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: 4.831896142681558
# Adjusted Reward for episode: 0.37168431866781215
# Collision!
# Worker saw 21 steps
# Sum of episode rewards: 204.8626691411408
# Adjusted Reward for episode: 9.75536519719718
# Worker saw 32 steps
# Sum of episode rewards: 938.9585602213834
# Adjusted Reward for episode: 29.342455006918232
# Worker saw 36 steps
# Sum of episode rewards: 1128.304823614917
# Adjusted Reward for episode: 31.34180065596992
# Step: 9 Reward: 31.34180065596992
# Time to complete update step: 562.4409198760986
# Performing step 9. (10/10)
# Worker saw 35 steps
# Sum of episode rewards: 889.8037489584246
# Adjusted Reward for episode: 25.42296425595499
# Collision!
# Worker saw 16 steps
# Sum of episode rewards: -222.43087008925656
# Adjusted Reward for episode: -13.901929380578535
# Worker saw 35 steps
# Sum of episode rewards: -428.4734793496622
# Adjusted Reward for episode: -12.242099409990349
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: 39.656215281041426
# Adjusted Reward for episode: 2.3327185459436133
# Collision!
# Worker saw 17 steps
# Sum of episode rewards: 10.456916776803752
# Adjusted Reward for episode: 0.6151127515766913
# Worker saw 35 steps
# Sum of episode rewards: -201.33632473213913
# Adjusted Reward for episode: -5.752466420918261
# Collision!
# Worker saw 26 steps
# Sum of episode rewards: -322.32550326173657
# Adjusted Reward for episode: -12.397134740836021
# Worker saw 35 steps
# Sum of episode rewards: -539.9457211220559
# Adjusted Reward for episode: -15.427020603487312
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -289.2907396986903
# Adjusted Reward for episode: -22.253133822976174
# Worker saw 35 steps
# Sum of episode rewards: -467.26263478217646
# Adjusted Reward for episode: -13.350360993776471
# Worker saw 35 steps
# Sum of episode rewards: -424.37611394534247
# Adjusted Reward for episode: -12.125031827009785
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 126.76115511238555
# Adjusted Reward for episode: 6.338057755619277
# Collision!
# Worker saw 13 steps
# Sum of episode rewards: -109.84580477230267
# Adjusted Reward for episode: -8.449677290177128
# Worker saw 36 steps
# Sum of episode rewards: -375.0817215545884
# Adjusted Reward for episode: -10.418936709849678
# Worker saw 35 steps
# Sum of episode rewards: 416.9933438041222
# Adjusted Reward for episode: 11.914095537260636
# Worker saw 34 steps
# Sum of episode rewards: 409.06672009723314
# Adjusted Reward for episode: 12.031374120506857
# Collision!
# Worker saw 30 steps
# Sum of episode rewards: 644.4564064153043
# Adjusted Reward for episode: 21.481880213843475
# Collision!
# Worker saw 27 steps
# Sum of episode rewards: 307.10773731823485
# Adjusted Reward for episode: 11.374360641416105
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -132.38599788777248
# Adjusted Reward for episode: -9.456142706269462
# Worker saw 35 steps
# Sum of episode rewards: -360.56940040946654
# Adjusted Reward for episode: -10.3019828688419
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -158.21353412008926
# Adjusted Reward for episode: -11.300966722863519
# Collision!
# Worker saw 20 steps
# Sum of episode rewards: 54.73936114314952
# Adjusted Reward for episode: 2.736968057157476
# Worker saw 34 steps
# Sum of episode rewards: 270.33669711870215
# Adjusted Reward for episode: 7.9510793270206515
# Worker saw 35 steps
# Sum of episode rewards: -483.9102264533074
# Adjusted Reward for episode: -13.826006470094498
# Worker saw 34 steps
# Sum of episode rewards: -382.49091013759227
# Adjusted Reward for episode: -11.249732651105655
# Collision!
# Worker saw 31 steps
# Sum of episode rewards: 627.9153993128073
# Adjusted Reward for episode: 20.25533546170346
# Worker saw 34 steps
# Sum of episode rewards: 874.983779560002
# Adjusted Reward for episode: 25.73481704588241
# Worker saw 36 steps
# Sum of episode rewards: -365.9684239191949
# Adjusted Reward for episode: -10.165789553310969
# Collision!
# Worker saw 21 steps
# Sum of episode rewards: 269.5687005198969
# Adjusted Reward for episode: 12.836604786661756
# Worker saw 34 steps
# Sum of episode rewards: -345.39456555837637
# Adjusted Reward for episode: -10.158663692893423
# Worker saw 35 steps
# Sum of episode rewards: -470.97581986896654
# Adjusted Reward for episode: -13.456451996256186
# Collision!
# Worker saw 14 steps
# Sum of episode rewards: -392.71161681946904
# Adjusted Reward for episode: -28.050829772819217
# Collision!
# Worker saw 24 steps
# Sum of episode rewards: 302.763523486812
# Adjusted Reward for episode: 12.6151468119505
# Step: 10 Reward: 12.6151468119505
# Time to complete update step: 566.145370721817

# %%
# We can see from the worker's reports of how many frames they saw that the FPS experienced by
# a worker is variable, which is why we computed the average reward per frame rather than
# the sum of rewards for each episode, since a worker experiencing more frames could make the
# episode reward appear artificially higher or lower without this adjustment.

# We can also see that the amount of time it takes to complete each update step is rather large,
# at ~10.5 minutes. This would make a 1000 iteration training session take 175 hours, which is 
# not feasible, and this is only with 16 deltas. This means we will need to have training done 
# in parallel.

# %%
# Plotting the results of our brief training session.
plt.figure(figsize=(11, 7))
plt.plot(ars_agent.history['step'], ars_agent.history['score'])
plt.title('Agent Score over Training Steps')
plt.xlabel('Training Step')
plt.ylabel('Score');

# %%
# A quick sanity check to make sure that our theta was changing each time
for i, theta in enumerate(ars_agent.history['theta']):
    if i + 1 == len(ars_agent.history['theta']):
        break
    if np.array_equal(theta, ars_agent.history['theta'][i+1]):
        print('same')
    else:
        print('different')
# Out:
# different
# different
# different
# different
# different
# different
# different
# different
# different

# %%
# Save weights for later use
ars_agent.save()

# %%
# Clean up actors and clear agent from memory
ars_agent.clean_up()
del(ars_agent)

# %%
# We can see that we have a functioning ARS Agent using our CarEnv environment, but training
# with a single car like this would take forever. We need to look into training cars in
# parallel. Fortunately, the authors of the 2018 paper have provided source code to run ARS
# training in parallel using Ray. As was necessary with the Skow code, this code needed to be
# heavily modified in order to work with the CarEnv. I have made liberal adjustments to their
# code for this study. My version of the code can be found in the ARS_Carla folder.

# %% [markdown]
# ### Continue to next notebook
# Click [here](notebook2_train_agent.ipynb) to proceed to the next notebook, where we train our agent using workers operating in parallel with the help of the Ray module.

# %% [markdown]
# ## Appendix
# This section contains dead code no longer used in this notebook, but stored down here for reference if needed. An attempt was made at using ipyparallel, which was not successful because it was unable to pickle the context objects, but luckily the Ray solution worked better.

# %%
# Skow's class to normalize inputs with rolling statistics
# Not used with the CarEnv since the outputs of the VGG19
# were all on the same scale, but it might be worth comparing
# using it later on.
class Normalizer():
    # Normalizes the inputs
    def __init__(self, nb_inputs):
        self.n = np.zeros(nb_inputs)
        self.mean = np.zeros(nb_inputs)
        self.mean_diff = np.zeros(nb_inputs)
        self.var = np.zeros(nb_inputs)

    def observe(self, x):
        self.n += 1.0
        last_mean = self.mean.copy()
        self.mean += (x - self.mean) / self.n
        self.mean_diff += (x - last_mean) * (x - self.mean)
        self.var = (self.mean_diff / self.n).clip(min = 1e-2)

    def normalize(self, inputs):
        obs_mean = self.mean
        obs_std = np.sqrt(self.var)
        return (inputs - obs_mean) / obs_std

# %%
# Original unmodified Skow Trainer class for reference
class ARSTrainer():
    def __init__(self,
                 hp=None,
                 input_size=None,
                 output_size=None,
                 normalizer=None,
                 policy=None,
                 monitor_dir=None):

        self.hp = hp or HP()
        np.random.seed(self.hp.seed)
        self.env = gym.make(self.hp.env_name)
        if monitor_dir is not None:
            should_record = lambda i: self.record_video
            self.env = wrappers.Monitor(self.env, monitor_dir, video_callable=should_record, force=True)
        self.hp.episode_length = self.hp.episode_length
        self.input_size = input_size or self.env.observation_space.shape[0]
        self.output_size = output_size or self.env.action_space.shape[0]
        self.normalizer = normalizer or Normalizer(self.input_size)
        self.policy = policy or Policy(self.input_size, self.output_size, self.hp)
        self.record_video = False

    # Explore the policy on one specific direction and over one episode
    def explore(self, direction=None, delta=None):
        state = self.env.reset()
        done = False
        num_plays = 0.0
        sum_rewards = 0.0
        while not done and num_plays < self.hp.episode_length:
            self.normalizer.observe(state)
            state = self.normalizer.normalize(state)
            action = self.policy.evaluate(state, delta, direction)
            state, reward, done, _ = self.env.step(action)
            reward = max(min(reward, 1), -1)
            sum_rewards += reward
            num_plays += 1
        return sum_rewards

    def train(self):
        for step in range(self.hp.nb_steps):
            # initialize the random noise deltas and the positive/negative rewards
            deltas = self.policy.sample_deltas()
            positive_rewards = [0] * self.hp.num_deltas
            negative_rewards = [0] * self.hp.num_deltas

            # play an episode each with positive deltas and negative deltas, collect rewards
            for k in range(self.hp.num_deltas):
                positive_rewards[k] = self.explore(direction="+", delta=deltas[k])
                negative_rewards[k] = self.explore(direction="-", delta=deltas[k])
                
            # Compute the standard deviation of all rewards
            sigma_rewards = np.array(positive_rewards + negative_rewards).std()

            # Sort the rollouts by the max(r_pos, r_neg) and select the deltas with best rewards
            scores = {k:max(r_pos, r_neg) for k,(r_pos,r_neg) in enumerate(zip(positive_rewards, negative_rewards))}
            order = sorted(scores.keys(), key = lambda x:scores[x], reverse = True)[:self.hp.num_best_deltas]
            rollouts = [(positive_rewards[k], negative_rewards[k], deltas[k]) for k in order]

            # Update the policy
            self.policy.update(rollouts, sigma_rewards)

            # Only record video during evaluation, every n steps
            if step % self.hp.record_every == 0:
                self.record_video = True
            # Play an episode with the new weights and print the score
            reward_evaluation = self.explore()
            print('Step: ', step, 'Reward: ', reward_evaluation)
            self.record_video = False

# %%
# This is an attempt to get the trainer to work with ipyparallel
# It did not work because ipyparallel will not pickle context objects
import ipyparallel as ipp
c = ipp.Client()
c[:].use_cloudpickle()

class ARSAgent_Parallel():
    def __init__(self,
                 hp=None,
                 num_envs=4,
                 base_model=True,
                 policy=None,
                 weights_dir='ars_weights',
                 initial_train=False
                ):

        self.hp = hp or HP()
        np.random.seed(self.hp.seed)
        self.envs = [CarEnv(control_type='continuous') for i in range(num_envs)]
        self.env = self.envs[0]
        self.output_size = self.env.action_space.shape[0]
        self.record_video = False
        self.history = {'step': [],
                        'score': [],
                        'theta': []}
        self.generate_theta = False
        self.historical_steps = 0
        
        if base_model is None:
            self.input_size = self.env.front_camera.shape
        else:
            base_model = VGG19(weights='imagenet', 
                               include_top=False, 
                               input_shape=(self.env.img_height, self.env.img_width,3))
            input_size = 1
            for dim in base_model.output_shape:
                if dim is not None:
                    input_size *= dim
            self.input_size = input_size
            
        if policy is None and initial_train == True:
            self.generate_theta = True
        self.base_model = base_model
        self.policy = policy or Policy(self.input_size, self.output_size, self.hp)
        self.weights_dir = mkdir('', weights_dir)
        
    # Explore the policy on one specific direction and over one episode
    def explore(self, direction=None, delta=None):
        state = self.env.reset()
        done = False
        sum_rewards = 0.0
        while not done:
            state = self.env.front_camera.reshape(1, 224, 224, 3)/255.
            if self.base_model:
                state = self.base_model.predict(state).flatten()
            else:
                state = state.flatten()
            action = self.policy.evaluate(state, delta, direction)
            state, reward, done, _ = self.env.step(action)
            reward = max(min(reward, 1), -1)
            sum_rewards += reward
        return sum_rewards

    # Explore the policy on one specific direction and over one episode
    def explore_directions(self, env):
        delta = np.random.randn(*self.policy.theta.shape)
        sum_positive_rewards = 0.0
        sum_negative_rewards = 0.0
        
        # Get positive direction for delta
        state = env.reset()
        done = False
        while not done:
            state = self.env.front_camera.reshape(1, 224, 224, 3)/255.
            if self.base_model:
                state = self.base_model.predict(state).flatten()
            else:
                state = state.flatten()
            action = self.policy.evaluate(state, delta, '+')
            state, reward, done, _ = self.env.step(action)
            #reward = max(min(reward, 1), -1)
            sum_positive_rewards += reward
            
        # Get negative direction for delta
        state = env.reset()
        done = False
        while not done:
            state = self.env.front_camera.reshape(1, 224, 224, 3)/255.
            if self.base_model:
                state = self.base_model.predict(state).flatten()
            else:
                state = state.flatten()
            action = self.policy.evaluate(state, delta, '-')
            state, reward, done, _ = self.env.step(action)
            reward = max(min(reward, 1), -1)
            sum_negative_rewards += reward
            
        return delta, sum_positive_rewards, sum_negative_rewards

    def train(self):
        if self.generate_theta:
            print('Training initial weights...')
            pred_model = keras.models.Sequential()
            base_model = VGG19(weights='imagenet', 
                               include_top=False, 
                               input_shape=(224, 224,3))
            for layer in base_model.layers:
                layer.trainable = False
            pred_model.add(base_model)
            pred_model.add(keras.layers.Flatten())
            pred_model.add(Dense(3, input_dim=base_model.output_shape, activation='linear'))
            pred_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
            X = train_imgs.reshape(50, 224, 224, 3)/255.
            y = np.array([1., 0., 0.])
            y = np.tile(y, (50, 1))
            pred_model.fit(X, y, epochs=5, workers=2)
            self.policy.theta = pred_model.get_weights()[-2].T
        
        for step in range(self.hp.nb_steps):
            print('Performing step {}. ({}/{})'.format(self.historical_steps,
                                                       step + 1,
                                                       self.hp.nb_steps
                                                      ))
            self.historical_steps += 1
            # Only record video during evaluation, every n steps
            if step % self.hp.record_every == 0:
                for env in self.envs:
                    env.show_cam = True
            # initialize the random noise deltas and the positive/negative rewards
            deltas = [] #self.policy.sample_deltas()
            positive_rewards = [] #[0] * self.hp.num_deltas
            negative_rewards = [] #[0] * self.hp.num_deltas

            # play an episode each with positive deltas and negative deltas, collect rewards
            for i in range(self.hp.num_deltas // 4):
                responses = c[:].map_sync(self.explore_directions, self.envs)
                for res in positive_responses:
                    deltas.append(res[0])
                    positive_rewards.append(res[1])
                    negative_rewards.append(res[3])
                
            # Compute the standard deviation of all rewards
            sigma_rewards = np.array(positive_rewards + negative_rewards).std()

            # Sort the rollouts by the max(r_pos, r_neg) and select the deltas with best rewards
            scores = {k:max(r_pos, r_neg) for k,(r_pos,r_neg) in enumerate(zip(positive_rewards, negative_rewards))}
            order = sorted(scores.keys(), key = lambda x:scores[x], reverse = True)[:self.hp.num_best_deltas]
            rollouts = [(positive_rewards[k], negative_rewards[k], deltas[k]) for k in order]

            # Update the policy
            self.policy.update(rollouts, sigma_rewards)

            if step % self.hp.record_every == 0:
                # Play an episode with the new weights and print the score
                reward_evaluation = self.run_episode()
                print('Step:', step + 1, 'Reward:', reward_evaluation)
                self.history['step'].append(self.historical_steps)
                self.history['score'].append(reward_evaluation)
                self.history['theta'].append(self.policy.theta.copy())
                
            self.env.show_cam = False
        
        save_file = mkdir(self.weights_dir, str(datetime.date.today()))
        np.savetxt(save_file+'/{}_episodes.csv'.format(self.historical_steps), 
                   self.policy.theta,
                   delimiter=','
                  )            
            
    def run_episode(self):
        return self.explore()
            
    def clean_up(self):
        for actor in self.env.actor_list:
            actor.destroy()
# Out:
# <AsyncResult: use_cloudpickle>

# %%
hp_test = HP(nb_steps=50, 
             noise=0.05, 
             learning_rate=0.02, 
             num_deltas=32, 
             num_best_deltas=16,
             record_every=1
            )

# %%
len(ars_agent.history['theta'])
# Out:
# 26

# %%
ars_agent_parallel = ARSAgent_Parallel(hp=hp_test)

# %%
weights = ars_agent.history['theta'][-1]

# %%
ars_agent_parallel.policy.theta = weights

# %%
ars_agent_parallel.train()
# Out:
# Performing step 0. (1/50)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-25b7e9e57fc3> in <module>
# ----> 1 ars_agent_parallel.train()
#
# <ipython-input-35-94f673d354b1> in train(self)
#     128             # play an episode each with positive deltas and negative deltas, collect rewards
#     129             for i in range(self.hp.num_deltas // 4):
# --> 130                 responses = c[:].map_sync(self.explore_directions, self.envs)
#     131                 for res in positive_responses:
#     132                     deltas.append(res[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\client\view.py in map_sync(self, f, *sequences, **kwargs)
#     342             raise TypeError("map_sync doesn't take a `block` keyword argument.")
#     343         kwargs['block'] = True
# --> 344         return self.map(f,*sequences,**kwargs)
#     345
#     346     def imap(self, f, *sequences, **kwargs):
#
# <C:\ProgramData\Anaconda3\lib\site-packages\decorator.py:decorator-gen-143> in map(self, f, *sequences, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\client\view.py in sync_results(f, self, *args, **kwargs)
#      50     self._in_sync_results = True
#      51     try:
# ---> 52         ret = f(self, *args, **kwargs)
#      53     finally:
#      54         self._in_sync_results = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\client\view.py in map(self, f, *sequences, **kwargs)
#     621         assert len(sequences) > 0, "must have some sequences to map onto!"
#     622         pf = ParallelFunction(self, f, block=block, **kwargs)
# --> 623         return pf.map(*sequences)
#     624
#     625     @sync_results
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\client\remotefunction.py in map(self, *sequences)
#     297         and mismatched sequence lengths will be padded with None.
#     298         """
# --> 299         return self(*sequences, __ipp_mapping=True)
#     300
#     301 __all__ = ['remote', 'parallel', 'RemoteFunction', 'ParallelFunction']
#
# <C:\ProgramData\Anaconda3\lib\site-packages\decorator.py:decorator-gen-133> in __call__(self, *sequences, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\client\remotefunction.py in sync_view_results(f, self, *args, **kwargs)
#      78     view = self.view
#      79     if view._in_sync_results:
# ---> 80         return f(self, *args, **kwargs)
#      81     view._in_sync_results = True
#      82     try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\client\remotefunction.py in __call__(self, *sequences, **kwargs)
#     251         futures = []
#     252
# --> 253         pf = PrePickled(self.func)
#     254
#     255         for index, t in enumerate(targets):
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\serialize\serialize.py in __init__(self, obj)
#      42     """
#      43     def __init__(self, obj):
# ---> 44         self.buffers = serialize_object(obj)
#      45
#      46
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipyparallel\serialize\serialize.py in serialize_object(obj, buffer_threshold, item_threshold)
#     123         buffers.extend(_extract_buffers(cobj, buffer_threshold))
#     124
# --> 125     buffers.insert(0, pickle.dumps(cobj, PICKLE_PROTOCOL))
#     126     return buffers
#     127
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in dumps(obj, protocol)
#    1123     try:
#    1124         cp = CloudPickler(file, protocol=protocol)
# -> 1125         cp.dump(obj)
#    1126         return file.getvalue()
#    1127     finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in dump(self, obj)
#     480         self.inject_addons()
#     481         try:
# --> 482             return Pickler.dump(self, obj)
#     483         except RuntimeError as e:
#     484             if 'recursion' in e.args[0]:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in dump(self, obj)
#     435         if self.proto >= 4:
#     436             self.framer.start_framing()
# --> 437         self.save(obj)
#     438         self.write(STOP)
#     439         self.framer.end_framing()
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in save_instancemethod(self, obj)
#     888         else:
#     889             if PY3:  # pragma: no branch
# --> 890                 self.save_reduce(types.MethodType, (obj.__func__, obj.__self__), obj=obj)
#     891             else:
#     892                 self.save_reduce(
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     636         else:
#     637             save(func)
# --> 638             save(args)
#     639             write(REDUCE)
#     640
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_tuple(self, obj)
#     772         if n <= 3 and self.proto >= 2:
#     773             for element in obj:
# --> 774                 save(element)
#     775             # Subtle.  Same as in the big comment below.
#     776             if id(obj) in memo:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     631                     "args[0] from __newobj__ args has the wrong class")
#     632             args = args[1:]
# --> 633             save(cls)
#     634             save(args)
#     635             write(NEWOBJ)
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in save_global(self, obj, name, pack)
#     875             Pickler.save_global(self, obj, name=name)
#     876         elif not _is_global(obj, name=name):
# --> 877             self.save_dynamic_class(obj)
#     878         else:
#     879             Pickler.save_global(self, obj, name=name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in save_dynamic_class(self, obj)
#     684         # Now save the rest of obj's __dict__. Any references to obj
#     685         # encountered while saving will point to the skeleton class.
# --> 686         save(clsdict)
#     687
#     688         # Write a tuple of (skeleton_class, clsdict).
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in save_function(self, obj, name)
#     554             return self.save_pypy_builtin_func(obj)
#     555         else:
# --> 556             return self.save_function_tuple(obj)
#     557
#     558     dispatch[types.FunctionType] = save_function
#
# C:\ProgramData\Anaconda3\lib\site-packages\cloudpickle\cloudpickle.py in save_function_tuple(self, func)
#     756         if hasattr(func, '__kwdefaults__'):
#     757             state['kwdefaults'] = func.__kwdefaults__
# --> 758         save(state)
#     759         write(pickle.TUPLE)
#     760         write(pickle.REDUCE)  # applies _fill_function on the tuple
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     632             args = args[1:]
#     633             save(cls)
# --> 634             save(args)
#     635             write(NEWOBJ)
#     636         else:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_tuple(self, obj)
#     787         write(MARK)
#     788         for element in obj:
# --> 789             save(element)
#     790
#     791         if id(obj) in memo:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_tuple(self, obj)
#     772         if n <= 3 and self.proto >= 2:
#     773             for element in obj:
# --> 774                 save(element)
#     775             # Subtle.  Same as in the big comment below.
#     776             if id(obj) in memo:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     547
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#     551     def persistent_id(self, obj):
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_tuple(self, obj)
#     772         if n <= 3 and self.proto >= 2:
#     773             for element in obj:
# --> 774                 save(element)
#     775             # Subtle.  Same as in the big comment below.
#     776             if id(obj) in memo:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# C:\ProgramData\Anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# C:\ProgramData\Anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     522             reduce = getattr(obj, "__reduce_ex__", None)
#     523             if reduce is not None:
# --> 524                 rv = reduce(self.proto)
#     525             else:
#     526                 reduce = getattr(obj, "__reduce__", None)
#
# TypeError: can't pickle Context objects

# %%
ars_agent_parallel.clean_up()

# %% [markdown]
# I'd like to try training in a variety of circumstances and with various combinations of inputs. The semantic segmentation cam may give great performance with camera-based training. There are also radar, lidar, and other sensors that can be added into the inputs. First, let's just set up a basic RGB cam and try to see what that can do. I am thinking that putting the VGG19 with imagenet weights in front of the ARS agent may help it find edges, so we need to compare both of these methods over a given number of episodes. Sentdex's scoring system is not badly designed, and it may be enlightening to know how my scores compare.
